# %% [markdown]
# https://drive.google.com/file/d/1D4SRYpyFxmxLVXdZmWwrR-WYja3eS-zt/view?usp=sharing   archivo cvs  con los  datos

# %% [markdown]
# Limpieza de datos

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("Crime_Data_from_2020_to_Present.csv")
data.head(5)
# Out:
#        DR_NO               Date Rptd                DATE OCC  TIME OCC  AREA  \
# 0  190326475  03/01/2020 12:00:00 AM  03/01/2020 12:00:00 AM      2130     7
# 1  200106753  02/09/2020 12:00:00 AM  02/08/2020 12:00:00 AM      1800     1
# 2  200320258  11/11/2020 12:00:00 AM  11/04/2020 12:00:00 AM      1700     3
# 3  200907217  05/10/2023 12:00:00 AM  03/10/2020 12:00:00 AM      2037     9
# 4  220614831  08/18/2022 12:00:00 AM  08/17/2020 12:00:00 AM      1200     6
#
#    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0   Wilshire          784         1     510
# 1    Central          182         1     330
# 2  Southwest          356         1     480
# 3   Van Nuys          964         1     343
# 4  Hollywood          666         2     354
#
#                                 Crm Cd Desc  ... Status   Status Desc  \
# 0                          VEHICLE - STOLEN  ...     AA  Adult Arrest
# 1                     BURGLARY FROM VEHICLE  ...     IC   Invest Cont
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 155311 entries, 0 to 155310
# Data columns (total 28 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   DR_NO           155311 non-null  int64
#  1   Date Rptd       155311 non-null  object
#  2   DATE OCC        155311 non-null  object
#  3   TIME OCC        155311 non-null  int64
#  4   AREA            155311 non-null  int64
#  5   AREA NAME       155311 non-null  object
#  6   Rpt Dist No     155311 non-null  int64
#  7   Part 1-2        155311 non-null  int64
#  8   Crm Cd          155311 non-null  int64
#  9   Crm Cd Desc     155311 non-null  object
#  10  Mocodes         134607 non-null  object
#  11  Vict Age        155311 non-null  int64
#  12  Vict Sex        135590 non-null  object
#  13  Vict Descent    135587 non-null  object
#  14  Premis Cd       155309 non-null  float64
#  15  Premis Desc     155253 non-null  object
# ...

# %%
df_freq = pd.DataFrame(data['DATE OCC'].copy())

df_freq['mes'] = df_freq['DATE OCC'].str.split("/").str[0]
df_freq['año'] = df_freq['DATE OCC'].str.split("/").str[2].str.split(" ").str[0]
df_freq['año'] = df_freq['año'].astype(int)

f_conteo = df_freq.groupby(['año', 'mes']).size().reset_index(name='conteo')
f_conteo = f_conteo.pivot('mes','año','conteo')
df_freq
# Out:
# <ipython-input-10-ec275e2843e9>:8: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   f_conteo = f_conteo.pivot('mes','año','conteo')
#                       DATE OCC mes   año
# 0       03/01/2020 12:00:00 AM  03  2020
# 1       02/08/2020 12:00:00 AM  02  2020
# 2       11/04/2020 12:00:00 AM  11  2020
# 3       03/10/2020 12:00:00 AM  03  2020
# 4       08/17/2020 12:00:00 AM  08  2020
# ...                        ...  ..   ...
# 155306  10/19/2020 12:00:00 AM  10  2020
# 155307  11/16/2020 12:00:00 AM  11  2020
# 155308  01/25/2020 12:00:00 AM  01  2020
# 155309  06/02/2020 12:00:00 AM  06  2020
# 155310  08/15/2020 12:00:00 AM  08  2020
#
# [155311 rows x 3 columns]

# %%
meses = {
    '01': 'enero',
    '02': 'febrero',
    '03': 'marzo',
    '04': 'abril',
    '05': 'mayo',
    '06': 'junio',
    '07': 'julio',
    '08': 'agosto',
    '09': 'septiembre',
    '10': 'octubre',
    '11': 'noviembre',
    '12': 'diciembre'
}

df_freq = pd.DataFrame(df['DATE OCC'].copy())
df_freq['DATE OCC'] = df_freq['DATE OCC'].str.split("/").str[0]
frecuencia = pd.DataFrame(df_freq['DATE OCC'].value_counts())
frecuencia = frecuencia.sort_index()
frecuencia = frecuencia.rename(index=meses)
frecuencia = frecuencia.rename(columns={'DATE OCC': 'absoluta'})
frecuencia['acumulada'] = frecuencia['absoluta'].cumsum()
frecuencia['relativa'] = frecuencia['absoluta']/frecuencia['acumulada'][-1]
frecuencia['relativa_acumulada'] = frecuencia['acumulada']/frecuencia['acumulada'][-1]
frecuencia
# Out:
#             absoluta  acumulada  relativa  relativa_acumulada
# enero          91589      91589  0.101612            0.101612
# febrero        77865     169454  0.086386            0.187999
# marzo          71293     240747  0.079095            0.267094
# abril          70387     311134  0.078090            0.345184
# mayo           73467     384601  0.081507            0.426691
# junio          73046     457647  0.081040            0.507731
# julio          75598     533245  0.083871            0.591602
# agosto         75280     608525  0.083519            0.675121
# septiembre     72424     680949  0.080350            0.755471
# octubre        75980     756929  0.084295            0.839766
# noviembre      71448     828377  0.079267            0.919033
# diciembre      72980     901357  0.080967            1.000000
