# %%
print("------------------------------ PUNTO 4--------------------------------")
import math
#A)
def factorial(n):
    """
    esta  funcion calcula el factorial n!
    Entrada----
    n : [int] numero entero
    Salida----
    Fac_n :[int] resultado del factorian n!

    """
    Fac_n=1
    if n!=0 or n!=1:
      for i in range(1,n+1):                                                    # cambie  la recursividad por un for por que  me estaba  dando errores  de profundidad
        Fac_n=Fac_n*i
    return Fac_n

def dobleFactorial(n):
    """
    Esta función calcula el doblefactorial de n.
    Entrada----
    n : [int] número entero
    Salida----
    resultado : [int] resultado del doblefactorial de n
    """
    resultado = 1
    while n > 0:
        resultado *= n
        n -= 2
    return resultado

def integral(m, n):
    """
    Esta función calcula la integral según las condiciones dadas.
    Entrada----
    m : [int] número entero
    n : [int] número entero
    Salida----
    resultado : [float] resultado de la integral
    """
    if m % 2==0 and n % 2 == 0:
        return (math.pi/2) * (dobleFactorial(m-1) * dobleFactorial(m-1)) / dobleFactorial(2*m)
    else:
        return (dobleFactorial(m-1) * dobleFactorial(n-1)) / dobleFactorial(n+m)

m=4
n=2
print("el resultado de la integral  para m={} y n={} (ambos  pares) es {}".format(m,n,integral(m, n)))

m=3
n=2
print("el resultado de la integral  para m={} y n={}  es {}".format(m,n,integral(m, n)))
# Out:
# ------------------------------ PUNTO 4--------------------------------
# el resultado de la integral  para m=4 y n=2 (ambos  pares) es 0.03681553890925539
# el resultado de la integral  para m=3 y n=2  es 0.13333333333333333
