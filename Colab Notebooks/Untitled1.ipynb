# %%
import pandas as pd

# %%
help(sort_values())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-feb15465a448> in <cell line: 1>()
# ----> 1 help(sort_values())
#
# NameError: name 'sort_values' is not defined
