# %%
# definimos el valor de las constantes

me=9.1094E-31                       # Masa del electron [Kg]
e=1.602E10-19                       # Carga del electron [C]
epsilon=8,854E-12                   # permitividad eléctrica [C]^2[s]^2/[kg][m]^3
h=6.626E10-34                       # Constante de Planck [J]
